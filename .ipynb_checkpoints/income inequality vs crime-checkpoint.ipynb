# %% [markdown]
# # Relationships Among Crime Rate, Gini Coefficient, and Median Income in US
#
# #### Juhyeok Kim and Yaeji Shin
#
# ## Objective
#
# The objective of this project is to analyze crime rate, gini coefficient, and median income of each State from 2019, and discover if there are factors that effect crime rate. Throughout this tutorial, we will attempt to see if there are trends among these topics by comparing data and research articles.
#
# ## Introduction
# We walked into this project with a preconceived notion of the effect of income inequality on crime rate. We expected there to be a positive correlation between income inequality and crime rate. However, after the data curation and analysis of the data we collected, we found out that there seemed to be no positive relationship between the two variables. There was no definite evidence of data that pointed towards the notion that, in general, income inequality increases the crime rate. Therefore, we decided to further investigate the cause of the increase in crime rate. So, we tried scraping data for median income and poverty rate for each state. However, although significantly more correlated with crime rate than income inequality, neither was significant enough to conclude that one led to another. At this time, we thought either our analysis was wrong or data was corrupted. So, we endeavored to research the relationship between crime rate and the variables we mentioned above. And, it turns out our data and analysis were matching up with the research done by the professionals. The professionals in the field suggest that there might be more factors that contribute more significantly to the rise of crime rate other than the three factors that we mentioned above. After this research, that is also the conclusion that we have come up with as well, that there may be causes more significant than disparity of income to crime rate or that the cause of crime rate is not just a cause but the compilation of causes.
#
# Although we looked through a lot of articles, we mainly focused on these two articles: “Examining the Relationship between Income Inequality and Varieties of Crime in the United States” and “The Effect of Income Inequality on Crime”. Here are the links if you are interested in reading about them before heading into the details of our analysis of our research:
# https://business.tcnj.edu/wp-content/uploads/sites/219/2013/07/Durante-thesis-2012.pdf
# https://smartech.gatech.edu/bitstream/handle/1853/54740/econ_3161_paper_Li_McAfee_Phadke.pdf
#
# ## Data Collection:
#
# Data was collected using the following tools:
#
# 1. requests
# 2. pandas
# 3. numpys
# 4. html5lib
# 6. BeautifulSoup
# 7. matplotlib

# %%
import re
import requests
from bs4 import BeautifulSoup
from os import path
try:
    import urllib
except ImportError:
    from urlparse import urlparse
import pandas
# import sys
# !{sys.executable} -m pip install lxml html5lib
import lxml
import html5lib
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame
from sklearn import linear_model

# %% [markdown]
# ### Gini Coefficient & Crime Rate
# First, we scraped the gini coefficient and crime rate from statistica.com. Our data includes the rates from each state in 2019. After scraping the data, we used pandas.DataFrame to read the html and find a table, and used BeautifulSoup to create a table. We merged the 2 data, gini coefficient and crime rate to create a single table with the 2 data from each state.

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:10.0.1) Gecko/20100101 Firefox/10.0.1'}

r = requests.get('https://www.statista.com/statistics/227249/greatest-gap-between-rich-and-poor-by-us-state/', headers=headers)

root = BeautifulSoup(r.text, 'html.parser')
table = root.find("table").prettify()

income_list = pandas.read_html(str(table), converters={"tbody": str})
income_table = pandas.DataFrame(income_list[0])
income_table.columns = ['States', 'Gini Coefficient']

crime = requests.get('https://www.statista.com/statistics/200445/reported-violent-crime-rate-in-the-us-states/', headers=headers)
crime_soup = BeautifulSoup(crime.text, 'html.parser')

# View the content and find the appropriate table
crime_table = crime_soup.find("table").prettify()

# Save the aforementioned table as a variable
crime_list = pandas.read_html(str(crime_table), converters={"tbody": str})
crime_list = crime_list[0]
crime_list.columns = ['States', 'Crime Rate']

data = crime_list.merge(income_table, how = "inner", left_on = "States", right_on = "States")

data
# Out:
#                   States  Crime Rate  Gini Coefficient
# 0   District of Columbia      1049.0              0.51
# 1                 Alaska       867.1              0.44
# 2             New Mexico       832.2              0.48
# 3              Tennessee       595.2              0.47
# 4               Arkansas       584.6              0.48
# 5              Louisiana       549.3              0.50
# 6         South Carolina       511.3              0.47
# 7                Alabama       510.8              0.47
# 8               Missouri       495.0              0.46
# 9                 Nevada       493.8              0.47
# 10               Arizona       455.3              0.46
# 11              Maryland       454.1              0.46
# 12            California       441.2              0.49
# 13              Michigan       437.4              0.46
# 14              Oklahoma       431.8              0.47
# 15              Delaware       422.6              0.45
# ...

# %% [markdown]
# ### Line graph of Gini Coefficent vs. Crime Rate for each state
# To visualize the data, we used matplotlib to create a linegraph with 2 y-axis, for gini coefficient and crime rate, and x-axis for states. From here on out, all graphs are sorted based on highest crime rate to lowest criem rate from left to right on the x-axis. Crime data is marked as red and gini coefficient is marked as blue.

# %%
fig, ax1 = plt.subplots()
color = 'tab:blue'

ax1.set_xlabel('States')
ax1.set_ylabel('Gini Coefficient', color=color)
ax1.plot(data['States'], data['Gini Coefficient'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
ax2.set_ylabel('Crime Rate', color=color)  # we already handled the x-label with ax1
ax2.plot(data['States'], data['Crime Rate'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
fig.autofmt_xdate(rotation=45)
plt.gcf().set_size_inches(20, 10)
# legend, title
plt.title('Gini Coefficent vs. Crime Rate for each state')

plt.show()

# %%
# Polynomial
gini_fit = np.polyfit(data.index, data['Gini Coefficient'], 1)
crime_fit = np.polyfit(data.index, data['Crime Rate'], 1)

# Scatter plot
color1 = 'tab:blue'
ax1 = data.plot(kind='scatter', x='States', y='Gini Coefficient', color=color1, alpha=0.5, figsize=(10, 7))
ax1.tick_params(labelrotation=90, axis='y', labelcolor=color1)

ax2 = ax1.twinx()
color2 = 'tab:red'
data.plot(kind='scatter', x='States', y= 'Crime Rate', color=color2, alpha=0.5, figsize=(10, 7), ax=ax2)
ax2.tick_params(axis='y', labelcolor=color2)

# Regression lines
ax1.plot(data.index, gini_fit[0] * data.index + gini_fit[1], color=color1, linewidth=2)
ax2.plot(data.index, crime_fit[0] * data.index + crime_fit[1], color=color2, linewidth=2)

# Regression equation
ax1.text(25, 0.5, 'y={:.2f}+{:.2f}*x'.format(gini_fit[1], gini_fit[0]), color=color1, size=12)
ax2.text(10, 200, 'y={:.2f}+{:.2f}*x'.format(crime_fit[1], crime_fit[0]), color=color2, size=12)

plt.setp(ax1.get_xticklabels(), rotation=45, ha='right')
plt.gcf().set_size_inches(20, 10)

# legend, title
plt.title('Gini Coefficent vs. Crime Rate for each state')

plt.show()

# %% [markdown]
# ### Analysis of Gini Coefficient vs. Crime Rate for each state
#
# Although the linear regression of Gini Coefficient suggests that the general trend follows the crime rate, it is so loosely correlated to conclude that Gini Coefficient is the defining factor that leads to the rise of crime rate. As shown by the line graph of Gini Coefficient, three of the highest peaks of income inequality belong to the states with lower crime rates. And, in general, the low and high points of income inequality seem too inconsistent to draw a positive relationship between the two variables. In fact, in his article, Durante suggests that the lack of opportunity and ability to participate in the labor market is more responsive to crime rates than explicitly income inequality. He says that wages in wholesale and retail trade had the largest negative impact on property crime and shows a research finding that a 10 percent increase in the opportunity wage predicts a 5.8 percent decrease in crime, which indicates that poor economic conditions incentivize the disenfranchised population to commit crimes rather than explicitly income inequality.

# %% [markdown]
# ### Median Income & Crime Rate
# Now we scrape data for median income from each state in 2019 and merge the data with the crime rate table. The new table includes data about crime rate and median income.

# %%
median_income = requests.get('https://www.statista.com/statistics/233170/median-household-income-in-the-united-states-by-state/', headers=headers)

income_soup = BeautifulSoup(median_income.text, 'html.parser')

# View the content and find the appropriate table
income_table = income_soup.find("table").prettify()

income_list = pandas.read_html(str(income_table), converters={"tbody": str})
income_list = income_list[0]
income_list.columns = ['States', 'Median Income']

# data comparing crime rate and median income
data2 = crime_list.merge(income_list, how = "inner", left_on = "States", right_on = "States")

data2
# Out:
#                   States  Crime Rate  Median Income
# 0   District of Columbia      1049.0          93111
# 1                 Alaska       867.1          78394
# 2             New Mexico       832.2          53113
# 3              Tennessee       595.2          56627
# 4               Arkansas       584.6          54539
# 5              Louisiana       549.3          51707
# 6         South Carolina       511.3          62028
# 7                Alabama       510.8          56200
# 8               Missouri       495.0          60597
# 9                 Nevada       493.8          70906
# 10               Arizona       455.3          70674
# 11              Maryland       454.1          95572
# 12            California       441.2          78105
# 13              Michigan       437.4          64119
# 14              Oklahoma       431.8          59397
# 15              Delaware       422.6          74194
# 16                 Texas       418.9          67444
# ...

# %% [markdown]
# ### Line graph of Median Income vs. Crime Rate for each state
# We used the data above to make a line graph of gini coefficient and crime rate, and x-axis for states. Crime data is marked as red and median income is marked as blue.

# %%
fig, ax1 = plt.subplots()

color = 'tab:blue'
ax1.set_xlabel('States')
ax1.set_ylabel('Median Income', color=color)
ax1.plot(data2['States'], data2['Median Income'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
ax2.set_ylabel('Crime Rate', color=color)  # we already handled the x-label with ax1
ax2.plot(data2['States'], data2['Crime Rate'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
fig.autofmt_xdate(rotation=45)
plt.gcf().set_size_inches(20, 10)
# legend, title
plt.title('Median Income vs. Crime Rate for each state')

plt.show()

# %%
# Polynomial
income_fit = np.polyfit(data2.index, data2['Median Income'], 1)
crime_fit = np.polyfit(data2.index, data2['Crime Rate'], 1)

# Scatter plot
color1 = 'tab:blue'
ax1 = data2.plot(kind='scatter', x='States', y='Median Income', color=color1, alpha=0.5, figsize=(10, 7))
ax1.tick_params(axis='y', labelcolor=color1)

ax2 = ax1.twinx()
color2 = 'tab:red'
data2.plot(kind='scatter', x='States', y= 'Crime Rate', color=color2, alpha=0.5, figsize=(10, 7), ax=ax2)
ax2.tick_params(axis='y', labelcolor=color2)

# Regression lines
ax1.plot(data2.index, income_fit[0] * data2.index + income_fit[1], color=color1, linewidth=2)
ax2.plot(data2.index, crime_fit[0] * data2.index + crime_fit[1], color=color2, linewidth=2)

# Regression equation
ax2.text(25, 800, 'y={:.2f}+{:.2f}*x'.format(income_fit[1], income_fit[0]), color=color1, size=12)
ax2.text(10, 200, 'y={:.2f}+{:.2f}*x'.format(crime_fit[1], crime_fit[0]), color=color2, size=12)
plt.setp(ax1.get_xticklabels(), rotation=45, ha='right')
plt.gcf().set_size_inches(20, 10)

# legend, title
plt.title('Median Income vs. Crime Rate for each state')

plt.show()

# %% [markdown]
# ### Analysis of Median Income vs. Crime Rate
#
# Again, although there seems to be a stronger correlation between median income and crime rate, the line graph indicates that the relationship is a little inconsistent. For example, in the middle section of the line graph, it shows that the median income is also on the decline when crime rate is decreasing. This fact goes against our hypothesis that lower median income indicates higher crime rate and higher median income indicates lower crime rate. However, this hypothesis is proven to be too generalized because this isn’t always the case according to our data. In his article, Durante explains the reasons for this outcome. He argues that this may be because the crime rate is dictated by the police reports. Therefore, even if a crime occured, without a police report that’s being filed, it may never be recorded, which means that crime rate in places with low median income may be low due to less police reports being filed. Also, this may affect the inconsistencies in the relationship between median income and crime rate all around.

# %% [markdown]
# ### Poverty Rate & Crime Rate
# Now we scrape data for poverty rate from each state in 2019 and merge the data with the crime rate table. The new table includes data about crime rate and poverty rate.

# %%
poverty = requests.get('https://worldpopulationreview.com/state-rankings/poverty-rate-by-state', headers=headers)

poverty_soup = BeautifulSoup(poverty.text, 'html.parser')

# View the content and find the appropriate table
poverty_table = poverty_soup.find("table").prettify()
poverty_list = pandas.read_html(str(poverty_table), converters={"tbody": str})
poverty_list = poverty_list[0]
poverty_list = poverty_list.drop(['Poverty'], axis=1)
poverty_list.columns = ['States', 'Poverty']
poverty_list['Poverty'] = poverty_list['Poverty'].str.replace(r'%', '')
poverty_list['Poverty'] = poverty_list['Poverty'].astype(float)

# data comparing crime rate and median income
data3 = crime_list.merge(poverty_list, how = "inner", left_on = "States", right_on = "States")

data3
# Out:
#             States  Crime Rate  Poverty
# 0           Alaska       867.1    10.61
# 1       New Mexico       832.2    19.57
# 2        Tennessee       595.2    15.17
# 3         Arkansas       584.6    16.79
# 4        Louisiana       549.3    18.91
# 5   South Carolina       511.3    14.79
# 6          Alabama       510.8    16.90
# 7         Missouri       495.0    13.58
# 8           Nevada       493.8    12.53
# 9          Arizona       455.3    14.80
# 10        Maryland       454.1     9.10
# 11      California       441.2    13.74
# 12        Michigan       437.4    14.50
# 13        Oklahoma       431.8    15.37
# 14        Delaware       422.6    11.17
# 15           Texas       418.9    14.30
# 16          Kansas       410.8    12.04
# 17        Illinois       406.9    12.92
# 18         Montana       404.9    12.80
# 19    South Dakota       399.0    12.53
# 20        Colorado       381.0    10.10
# 21         Florida       378.4    13.57
# ...

# %% [markdown]
# ### Line graph of Poverty rate vs. Crime Rate for each state
# We used the data above to make a line graph of poverty rate and crime rate, and x-axis for states. Crime data is marked as red and poverty rate is marked as blue.

# %%
fig, ax1 = plt.subplots()

color = 'tab:blue'
ax1.set_xlabel('States')
ax1.set_ylabel('Poverty', color=color)
ax1.plot(data3['States'], data3['Poverty'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
ax2.set_ylabel('Crime Rate', color=color)  # we already handled the x-label with ax1
ax2.plot(data3['States'], data3['Crime Rate'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.autofmt_xdate(rotation=45)
plt.gcf().set_size_inches(20, 10)
fig.tight_layout()  # otherwise the right y-label is slightly clipped

# legend, title
plt.title('Poverty rate (%) vs. Crime Rate for each state')

plt.show()

# %%
# Polynomial
poverty_fit = np.polyfit(data3.index, data3['Poverty'], 1)
crime_fit = np.polyfit(data3.index, data3['Crime Rate'], 1)

# Scatter plot
color1 = 'tab:blue'
ax1 = data3.plot(kind='scatter', x='States', y='Poverty', color=color1, alpha=0.5, figsize=(10, 7))
ax1.tick_params(axis='y', labelcolor=color1)

ax2 = ax1.twinx()
color2 = 'tab:red'
data3.plot(kind='scatter', x='States', y= 'Crime Rate', color=color2, alpha=0.5, figsize=(10, 7), ax=ax2)
ax2.tick_params(axis='y', labelcolor=color2)

# Regression lines
plt.xticks(rotation=70)
ax1.plot(data3.index, poverty_fit[0] * data3.index + poverty_fit[1], color=color1, linewidth=2)
ax2.plot(data3.index, crime_fit[0] * data3.index + crime_fit[1], color=color2, linewidth=2)

# Regression equation
ax1.text(10, 20, 'y={:.2f}+{:.2f}*x'.format(poverty_fit[1], poverty_fit[0]), color=color1, size=12)
ax2.text(40, 600, 'y={:.2f}+{:.2f}*x'.format(crime_fit[1], crime_fit[0]), color=color2, size=12)
plt.setp(ax1.get_xticklabels(), rotation=45, ha='right')
plt.gcf().set_size_inches(20, 10)

# legend, title
plt.title('Poverty rate (%) vs. Crime Rate for each state')

plt.show()

# %% [markdown]
# ### Analysis of Poverty Rate and Crime Rate
#
# Although the linear regression of poverty rate indicates that poverty goes down along with crime rate. However, this relationship also seems rather inconsistent because three of the highest peaks occur in states with the bottom half of crime rate. Also, from Kansas to Pennsylvania, it seems as if the poverty rate is trending upwards when the crime rate is decreasing. Therefore, as with other relationships of data, the relationship between poverty rate and crime rate seem to be loosely correlated. In fact, Durante also states that the unemployment rate and poverty rate were not significant in his property-crime  model: [violent, property]crime = β1gini + β2unemployment + β3age1824 + β4poverty – β5age65 – β6female + β7popdensity + c + ε. He explains that this may be due to the low quality of police reports in more impoverished areas and the high level of police departments’ recording-keeping in high income areas.

# %%
poverty = []
crime = []
for index, row in data3.iterrows():
    poverty.append(row['Poverty'])
    crime.append(row['Crime Rate'])

p_ = []
for p in poverty:
    p_.append([p])
    
clf = linear_model.LinearRegression()
clf.fit(p_, crime)
predicted = clf.predict(p_)

plt.plot(poverty, crime, 'o')
plt.plot(poverty, predicted)
plt.title("crime rate vs. poverty")
plt.xlabel("Poverty (%)")
plt.ylabel("Crime Rate")
plt.show()

# %%
print(clf.score(p_, crime))
clf.predict([[25]])
# Out:
# 0.19506110439024715
# array([649.50359715])

# %% [markdown]
# Our model predicts that there would be about 650 crimes if the poverty level was at 25%. But since our R^2 is 0.19, our poverty and crime rate model may not have as accurate of a prediction. More information about how LinearRegression and predictions work could be found here: :http://scikit-learn.org/dev/modules/generated/sklearn.linear_model.LinearRegression.html

# %% [markdown]
# ### Conclusion
#
# Our initial hypothesis was that as income inequality increases, crime rate will also increase. However, this was proven incorrect by the analysis of our data and research done by professionals of this field. And, not just income inequality but other factors, such as median income and poverty rate, seem to not form a significant enough relationship with crime rate. Li, McAfee, and Phadke believe that this counter-intuitiveness may be due to missing variables and incomplete data. They say that a common problem with their data was the misrepresentation of crime rates in counties that contained large cities, that the crime reports were created without the inputs from the police department. Therefore, although many of the reports have been deleted, they believe that other data points had similar issues. Also, they suggest that poverty level does not vary geographically and can be inaccurate in comparisons between counties with vastly different costs of living. We believe that the same can be applied to different states when comparing poverty levels, which might have impacted the results of our dataset when making a relationship with crime rate. We also speculate that there might be other factors, such as population density, the percentage of females in a population, economic conditions, etc., that may have more positive correlation with crime rate. For example, Durante states in this article that there is a positive relationship between the percentage of males, ages from 18 to 24, and crime rate. Therefore, in conclusion, we believe that our initial hypothesis is false and requires further research that uses locally accurate dataset, that consider other factors, and that can capture important differences between states.
